# %% [markdown]
# ## Introduction
#
# ### POI - person of interest
#
# What is a person of interest?
#
# - indicted
# - settled without admitting guilt
# - testified in exchange for immunity
#
# poi.txt
# - manually created by Katie
# - 35 people, 5 from other firms
# - list may not be perfect
# - should be checked for accuracy

# %% [markdown]
# ### Accuracy vs. Training set size
#
# Size of training set has a big effect on accuracy.
#
# The bigger the training set size,  the better the accuracy but it plateaus.

# %%
from IPython.display import Image

# %%
Image('accuracy_vs_trainingsetsize.png')

# %% [markdown]
# Limitations:
#
# - amount data is limited sometimes
#
# - only 30 POI found, is that enough? katie didn't know. just try.
#
# In general,
#
# MORE DATA > > Fine-tuned algorithm

# %% [markdown]
# ### Downloading Enron Data
#
# https://www.cs.cmu.edu/~./enron/
#
# Download takes a while. After download, unzip:
#
# ```
# tar -xvzf filename.tgz
# ```
#
# In the current version of the corpus (2015-05-07), the "maildir" directory may be expanded without any parent directory.
#
# Question is, how many of the POI do we have emails from?
#
# -- done by hand, look for names in the directory
#
# -- poi.txt: y/n - poi or not (not all people in poi have emails in the list)
#
# So data is problematic.

# %% [markdown]
# ### Types of data
#
# - numerical
# - categorical
# - time series - temporal value (date, timestamp)
# - text
#
# --> influence what algorithm to use
